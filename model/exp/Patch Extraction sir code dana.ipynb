# %%
import os
import zipfile
import random
import numpy as np
# %tensorflow_version 2.x
# import tensorflow as tf
# from tensorflow.keras.optimizers import RMSprop
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile

# %%
# !wget --no-check-certificate \
    "https://storage.googleapis.com/datsets/DRIVE.zip"\
    -O "/tmp/DRIVE.zip"

local_zip = '/tmp/DRIVE.zip'
zip_ref   = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Out:
# --2020-03-02 12:45:40--  https://storage.googleapis.com/datsets/DRIVE.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.12.240, 2607:f8b0:4004:814::2010
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.12.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29756930 (28M) [application/x-zip-compressed]
# Saving to: ‘/tmp/DRIVE.zip’
#
# /tmp/DRIVE.zip      100%[===================>]  28.38M  --.-KB/s    in 0.1s
#
# 2020-03-02 12:45:40 (204 MB/s) - ‘/tmp/DRIVE.zip’ saved [29756930/29756930]

# %%
import glob
import cv2
from PIL import Image

images = [np.array(Image.open(file)) for file in glob.glob("/tmp/DRIVE/training/images/*.tif")]

# %%
len(images)
# Out:
# 20

# %%
def create_patch(imgs,patch_size):
    ps=patch_size//2
    image_patches=[]
    for k in range(0,2):
        padded_imgs=np.pad(imgs[k],pad_width=ps,mode='edge')
        for i in range(0,imgs[k].shape[0]):
            for j in range(0,imgs[k].shape[1]):
                flatten_imgs=padded_imgs[i:i+patch_size,j:j+patch_size].ravel()
                imgs_mod_flatten=np.hstack((flatten_imgs))
                image_patches.append(imgs_mod_flatten)
    image_patches=np.vstack(image_patches)
    return image_patches

# %% [markdown]
# # New Section

# %%
img = create_patch(images,(25))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-855789bea0eb> in <module>()
# ----> 1 img = create_patch(images,(25))
#
# <ipython-input-5-4ae4aed6c43e> in create_patch(imgs, patch_size)
#       7             for j in range(0,imgs[k].shape[1]):
#       8                 flatten_imgs=padded_imgs[i:i+patch_size,j:j+patch_size].ravel()
# ----> 9                 imgs_mod_flatten=np.hstack((flatten_imgs))
#      10                 image_patches.append(imgs_mod_flatten)
#      11     image_patches=np.vstack(image_patches)
#
# <__array_function__ internals> in hstack(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/shape_base.py in hstack(tup)
#     335         _arrays_for_stack_dispatcher(tup, stacklevel=2)
#     336
# --> 337     arrs = atleast_1d(*tup)
#     338     if not isinstance(arrs, list):
#     339         arrs = [arrs]
#
# <__array_function__ internals> in atleast_1d(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/shape_base.py in atleast_1d(*arys)
#      22
#      23
# ---> 24 @array_function_dispatch(_atleast_1d_dispatcher)
#      25 def atleast_1d(*arys):
#      26     """
#
# KeyboardInterrupt:

# %%
from PIL import Image
Image.open('D:/google drive/Missions/mission Retina/navdeep sir datasets/DRIVE/training/images/21_training.tif')
