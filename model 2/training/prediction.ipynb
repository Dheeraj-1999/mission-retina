# %%
import tensorflow as tf

# %%
import subprocess,sys
# !wget --no-check-certificate \
    "https://storage.googleapis.com/datsets/model2/model2nd11by11alldatasets.zip"\
    -O "/tmp/model2nd11by11alldatasets.zip"

zipFile = '/tmp/model2nd11by11alldatasets.zip'
destinationDirectory='/tmp'
subprocess.Popen(["7z", "e", f"{zipFile}", f"-o{destinationDirectory}", "-y"])
# Out:
# --2020-05-07 13:53:39--  https://storage.googleapis.com/datsets/model2/model2nd11by11alldatasets.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.111.128, 2607:f8b0:4001:c12::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.111.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6057808 (5.8M) [application/zip]
# Saving to: ‘/tmp/model2nd11by11alldatasets.zip’
#
# /tmp/model2nd11by11 100%[===================>]   5.78M  --.-KB/s    in 0.1s
#
# 2020-05-07 13:53:39 (43.9 MB/s) - ‘/tmp/model2nd11by11alldatasets.zip’ saved [6057808/6057808]

# %%
model=tf.keras.models.load_model('/tmp/model2nd11by11alldatasets.hdf5')

# %%
import subprocess,sys
# !wget --no-check-certificate \
    "https://storage.googleapis.com/datsets/Testing%20Data/STARETest.zip"\
    -O "/tmp/STARETest.zip"

zipFile = '/tmp/STARETest.zip'
destinationDirectory='/tmp'
subprocess.Popen(["7z", "e", f"{zipFile}", f"-o{destinationDirectory}", "-y"])
# Out:
# --2020-05-07 13:56:50--  https://storage.googleapis.com/datsets/Testing%20Data/STARETest.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.212.128, 2607:f8b0:4001:c12::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.212.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55414627 (53M) [application/zip]
# Saving to: ‘/tmp/STARETest.zip’
#
# /tmp/STARETest.zip  100%[===================>]  52.85M  57.0MB/s    in 0.9s
#
# 2020-05-07 13:56:51 (57.0 MB/s) - ‘/tmp/STARETest.zip’ saved [55414627/55414627]

# %%
import numpy as np
test = []
test.append(np.load('/tmp/patches11n11test0162.npy'))
test.append(np.load('/tmp/patches11n11test0255.npy'))
test.append(np.load('/tmp/patches11n11test0291.npy'))

# %%
np.array(test[0]).shape
# Out:
# (423500, 11, 11, 3)

# %%
predict = []
for i in range(3):
  predict.append(model.predict_classes(test[i]))
# Out:
# WARNING:tensorflow:From <ipython-input-18-002ae0f14dfa>:3: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-002ae0f14dfa> in <module>()
#       2 for i in range(3):
#       3   predict.append(model.predict_classes(test[i]))
# ----> 4 print(predict.shape)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
print(np.array(predict).shape)
# Out:
# (3, 423500, 1)

# %%
np.save('/content/predict.npy', predict)
