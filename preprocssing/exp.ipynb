# %%
import os
if not os.getcwd()=='D:\\google drive\\Missions\\mission Retina\\dataset\\navdeep sir datasets\\Stare':
    os.chdir('D:\\google drive\\Missions\\mission Retina\\dataset\\navdeep sir datasets\\Stare')
img_path = os.getcwd()+'/im0001.ppm'

# %%
import matplotlib.pyplot as plt

# %%
imgPPM = plt.imread(img_path)
plt.imshow(imgPPM)

# %%
# import os
if not os.getcwd()=='D:\\google drive\\Missions\\mission Retina\\dataset\\navdeep sir datasets\\StareJpg':
    os.chdir('D:\\google drive\\Missions\\mission Retina\\dataset\\navdeep sir datasets\\StareJpg')
img_path2 = os.getcwd()+'/1.jpg'

# %%
imgJpg = plt.imread(img_path)
plt.imshow(imgJpg)

# %%
import numpy as np
np.array_equal(imgPPM, imgJpg)
# Out:
# True

# %%
imgJpg.all
