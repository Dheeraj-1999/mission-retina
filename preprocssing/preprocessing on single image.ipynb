# %%
import skimage as sk
from skimage import io
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3d43bfad87b0> in <module>
# ----> 1 import skimage as sk
#       2 from skimage import io
#
# ModuleNotFoundError: No module named 'skimage'

# %%
import os
if not os.getcwd()=='D:\\google drive\\Missions\\mission Retina\\dataset\\navdeep sir datasets\\DRIVE\\maskedimgs':
    os.chdir('D:\\google drive\\Missions\\mission Retina\\dataset\\navdeep sir datasets\\DRIVE\\maskedimgs')
img_path = os.getcwd()+'/21.jpg'
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-06cd40c0b2bb> in <module>
#       1 import os
#       2 if not os.getcwd()=='D:\\google drive\\Missions\\mission Retina\\dataset\\navdeep sir datasets\\DRIVE\\maskedimgs':
# ----> 3     os.chdir('D:\\google drive\\Missions\\mission Retina\\dataset\\navdeep sir datasets\\DRIVE\\maskedimgs')
#       4 img_path = os.getcwd()+'/21.jpg'
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'D:\\google drive\\Missions\\mission Retina\\dataset\\navdeep sir datasets\\DRIVE\\maskedimgs'

# %%
image = io.imread(img_path)
image.shape
# Dimg = sk.transform.downscale_local_mean(image, (3,3,3) )
resized_img = sk.transform.resize(image, (200,200,3))
rescaled_img = sk.transform.rescale(image, 1.0/4.0, anti_aliasing=True)
# Out:
# D:\programs\anaconda\lib\site-packages\skimage\transform\_warps.py:23: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '

# %% [markdown]
# # SkImage.Tranforms methods

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,8))
fig.add_subplot(2, 2, 1)
plt.title('resized_img')
plt.imshow(resized_img)
fig.add_subplot(2, 2, 2)
plt.title('reshaped_img')
plt.imshow(rescaled_img)
fig.add_subplot(2, 2, 3)
plt.title('img')
plt.imshow(image)

plt.show()

# %% [markdown]
# # skimage.filters for edge detection

# %%
from skimage.feature import canny
import cv2

# %%
import skimage
image_gray = io.imread(img_path, as_gray=True)
img_robert = skimage.filters.roberts(image_gray)
img_sobel = skimage.filters.sobel(image_gray)
img_scharr = skimage.filters.scharr(image_gray)
img_canny = canny(image_gray, sigma = 0)

# %%
image.shape
# Out:
# (584, 565, 3)

# %%
# plt.imshow(img_robert)
row = 3
col = 3
fig = plt.figure(figsize=(16,16))
fig.add_subplot(row, col, 1)
plt.title('robert_img')
plt.imshow(img_robert, cmap='gray')

fig.add_subplot(row, col, 2)
plt.title('sobel_img')
plt.imshow(img_sobel, cmap='gray')

fig.add_subplot(row, col, 3)
plt.title('scharr_img')
plt.imshow(img_scharr, cmap='gray')

fig.add_subplot(row, col, 4)
plt.title('canny_img')
plt.imshow(img_canny, cmap='gray')


# fig.add_subplot(row, col, 5)
# plt.title('img')
# plt.imshow(img_clahe)

plt.show()

# %% [markdown]
# #  clahe

# %% [markdown]
# ## Accepted

# %%
bgr = cv2.imread(img_path)
# print(bgr.shape)
lab = cv2.cvtColor(bgr, cv2.COLOR_BGR2LAB)
# plt.imshow(cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB))
lab_planes = cv2.split(lab)
clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(7,7))
# print(np.array(lab_planes).shape)
lab_planes[0] = clahe.apply(lab_planes[0])
lab_planes[1] = clahe.apply(lab_planes[1])
lab_planes[2] = clahe.apply(lab_planes[2])
lab = cv2.merge(lab_planes)
bgr = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)
img_clahe_lab1_original = (cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB))

# %%
bgr = cv2.imread(img_path)
# print(bgr.shape)
lab = cv2.cvtColor(bgr, cv2.COLOR_BGR2LAB)
# plt.imshow(cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB))
lab_planes = cv2.split(lab)
clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
# print(np.array(lab_planes).shape)
lab_planes[0] = clahe.apply(lab_planes[0])
lab_planes[1] = clahe.apply(lab_planes[1])
lab_planes[2] = clahe.apply(lab_planes[2])
lab = cv2.merge(lab_planes)
bgr = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)
img_clahe_lab1 = (cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB))
# cv2.imwrite(imgname,bgr)

# %%
bgr = cv2.imread(img_path)
lab = cv2.cvtColor(bgr, cv2.COLOR_BGR2LAB)
lab_planes = cv2.split(lab)
clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(10,10))
# lab_planes[1] = clahe.apply(lab_planes[1])
lab_planes[0] = clahe.apply(lab_planes[0])
lab = cv2.merge(lab_planes)
bgr = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)
img_clahe_lab2 = (cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB))
#     cv2.imwrite(imgname,bgr)

# %%
rgb = io.imread(img_path)
# lab = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)
# plt.imshow(cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB))
rgb_planes = cv2.split(rgb)
clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(20,20))
# print(np.array(rgb_planes).shape)
rgb_planes[0] = clahe.apply(rgb_planes[0])
rgb_planes[1] = clahe.apply(rgb_planes[1])
rgb_planes[2] = clahe.apply(rgb_planes[2])
img_clahe_rgb = cv2.merge(rgb_planes)
# plt.imshow(img_clahe)
# bgr = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)
# cv2.imwrite(imgname,bgr)

# %%
row = 1
col = 3
fig = plt.figure(figsize=(16,16))
fig.add_subplot(row, col, 1)
plt.title('img_clahe_lab1_original')
plt.imshow(img_clahe_lab1_original)

# fig = plt.figure(figsize=(16,16))
fig.add_subplot(row, col, 2)
plt.title('img_lab1')
plt.imshow(img_clahe_lab1)

fig.add_subplot(row, col, 3)
plt.title('img_clahe_lab2')
plt.imshow(img_clahe_lab2)

# %% [markdown]
# # Gaussian

# %%
import scipy

# %%
plt.imshow(scipy.ndimage.filters.gaussian_filter(img_clahe_lab1_original, sigma=1))

# %%
from scipy.ndimage import filters

# %% [markdown]
# # Median filter

# %%
plt.imshow(filters.median_filter(img_clahe_lab1_original, size=1))

# %% [markdown]
# # Non Local Median filter

# %%
img_clahe_lab1_original = skimage.img_as_float(img_clahe_lab1_original)
plt.imshow(img_clahe_lab1_original)

# %% [markdown]
# # Image : Clahe->DeNoise Median

# %%
import numpy as np
from skimage.restoration import denoise_nl_means, estimate_sigma
# sigma = 0.08
# noisy = skimage.util.random_noise(img_clahe_lab1_original, var=sigma**2)

# estimate the noise standard deviation from the noisy image
sigma_est = np.mean(estimate_sigma(img_clahe_lab1_original, multichannel=True))
# print(f"estimated noise standard deviation = {sigma_est}")

patch_kw = dict(patch_size=10,      # 5x5 patches
                patch_distance=6,  # 13x13 search area
                multichannel=True)

# slow algorithm
# denoise = denoise_nl_means(img_clahe_lab1_original, h=1.15 * sigma_est, fast_mode=False,
#                            **patch_kw)

# slow algorithm, sigma provided
img_clahe_denoise2 = denoise_nl_means(img_clahe_lab1_original, h=0.8 * sigma_est, sigma=sigma_est,
                            fast_mode=False, **patch_kw)

# fast algorithm
# denoise_fast = denoise_nl_means(img_clahe_lab1_original, h=0.8 * sigma_est, fast_mode=True,
#                                 **patch_kw)

# # fast algorithm, sigma provided
# denoise2_fast = denoise_nl_means(img_clahe_lab1_original, h=0.6 * sigma_est, sigma=sigma_est,
#                                  fast_mode=True, **patch_kw

# %%
row = 1
col = 2
fig = plt.figure(figsize=(32,32))
# fig.add_subplot(row, col, 1)
# plt.title('denoise')
# plt.imshow(denoise)

# fig = plt.figure(figsize=(16,16))
fig.add_subplot(row, col, 1)
plt.title('denoise2')
plt.imshow(img_clahe_denoise2)

# fig.add_subplot(row, col, 3)
# plt.title('denoise_fast')
# plt.imshow(denoise_fast)

# fig.add_subplot(row, col, 4)
# plt.title('denoise2_fast')
# plt.imshow(denoise2_fast)

fig.add_subplot(row, col,2)
plt.title('img_lab_original')
plt.imshow(img_clahe_lab1_original)

# %%
from skimage import img_as_float, img_as_ubyte
img_clahe_denoise = img_as_ubyte(img_clahe_denoise2)

# %%
plt.hist(img_clahe_denoise.flat, bins = 70, range=(0,255))
# Out:
# (array([ 23392., 148851., 129125.,   8258.,   1602.,    470.,    470.,
#            401.,    312.,    376.,    400.,    314.,    383.,    320.,
#            430.,    754.,   1423.,   4958.,  19992.,  37269.,  64512.,
#          48295.,  19204.,  13502.,   8034.,   4954.,   8486.,   8746.,
#          15402.,  29629.,  28963.,  31447.,  25874.,  16520.,  18303.,
#          13151.,   7410.,   7927.,   6968.,   5065.,   6714.,   5141.,
#           7296.,   7722.,   6668.,   9122.,   8513.,   6163.,   7496.,
#           6802.,   5678.,   8306.,   8741.,   7280.,   9325.,   6992.,
#           8937.,   9059.,   7840.,  11602.,  11707.,   8441.,  10275.,
#           9416.,   6521.,   7170.,   5600.,   3229.,   3491.,   6741.]),
#  array([  0.        ,   3.64285714,   7.28571429,  10.92857143,
#          14.57142857,  18.21428571,  21.85714286,  25.5       ,
#          29.14285714,  32.78571429,  36.42857143,  40.07142857,
#          43.71428571,  47.35714286,  51.        ,  54.64285714,
# ...
